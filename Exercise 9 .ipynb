# %%
def square (x):
    return x*x

# %%
square(2)
# Out:
# 4

# %%
numbers = [1,2,3,4,5,6]

# %% [markdown]
# list(map(square,numbers))

# %% [markdown]
# # Filter ##

# %%
def odd(x):
    return x%2 == 1

# %%
odd(7)
# Out:
# True

# %%
list(filter(odd,numbers))
# Out:
# [1, 3, 5]

# %%
import functools

def sum2(x,y):
    print(x,y)
    #x = x + y
    return x + y

def sum3(x,y):
    return x * y

functools.reduce(sum3,numbers)
# Out:
# 720

# %%
numbersPlusOne = map(lambda x: x + 1, numbers)

# %%
list(numbersPlusOne)
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
degrees = [40,23,53,100,32]

# %%
mult = lambda x: x*x

# %%
mult(3)
# Out:
# 9

# %%
list(map(lambda x,y: x + y, numbers, degrees))
# Out:
# [41, 25, 56, 104, 37]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list(filter(lambda x: x%2 == 0, numbers))
# Out:
# [2, 4, 6]

# %%
functools.reduce(lambda x,y: x+y, numbers)
# Out:
# 21

# %%
import math
math.floor(2.2)
# Out:
# 2

# %%
import os

os.system("NotePad")
# Out:
# 32512

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EXCL',
#  'O_EXLOCK',
#  'O_NDELAY',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NONBLOCK',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SHLOCK',
#  'O_SYNC',
#  'O_TRUNC',
#  'O_WRONLY',
#  'PRIO_PGRP',
#  'PRIO_PROCESS',
#  'PRIO_USER',
#  'P_ALL',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_PGID',
#  'P_PID',
#  'P_WAIT',
#  'PathLike',
#  'RTLD_GLOBAL',
#  'RTLD_LAZY',
#  'RTLD_LOCAL',
#  'RTLD_NODELETE',
#  'RTLD_NOLOAD',
#  'RTLD_NOW',
# ...

# %%
import urllib

# %%
import zlib

# %%
aliceFile = open("aliceinwonder.txt", "rb")
contents = aliceFile.read()

# %%
compressedContents = zlib.compress(contents)

# %%
compressedContents
# Out:
# b'x\x9c\xbc\xbd]s\x1b\xd7\xb2%\xf8\xae\x08\xfd\x87\xa2\xe7\x01\xf6\r\x90\xd1\xdd3\x131M=(d\x89>\xe2\xbd\xb2\xe4\x96\xe4\xe3\xf0tLL\x14\x81"P&P\x85[U\x10\x8d\xf3\xeb\'\xd7Z\x99{\xef\x02\xe9so\xbfL\x7f\x1c\x8b$P\x1f{\xe7\xce\xcf\x95+\x7f\x19\xfa?\x9a\xd5T\xfd\xed85\xdd]3l\x16c\xf5f\xd7\xae\x1a\xfcw\xfd\xad\xe9\xa6\xe3\xd0\x8cU\xdbU\xbf\xf5\xdd\xba\x19vu\xb7^Vw\xa7\xeaC\xf3\xd8\x8e\xd5\xdbz\x18\xfa\xdd\xee\xe5\x8b\x97/\xben\xed\xe7\xe6\xc7\xbe\x7f\xa8\xec\x1f\xf7\xfdPM\xdb\xa6:\x8eM\xd5\xdfWuw\xea\xbb\x06\xffy\xdc6\x83\xfdc\xaa\xba\xbeZ\xf5\xe3d\xbf[W\x8f\xed\xb4}\xf9\xa2\xde\xed\xf1\x0b\xfb\x83\xddr\x1a\xda\xd5\xd4\xf6\xddX=n\xebi\xec\x9bo\xcdpUU\xbf\xf7\xc7j_\x9f\xec\xab\x87S\xd5N\xcbj\xd3~k\xec\x1fU\xfdh\xbf\xed\x87\x97/\x86\xe6\x127\xb5_\x1d\xf1\xc0|\x8a\xa9\x19\xf6#\x9e\x03?\xfcr\xfe\xca\xd5\x07{\xdf\x0e\xdf\xe9V\xbb\xe3\xbaY\xbf|\x81\x07\xb2\x0f\xa77\xb2\xb7\xe9\xbb]\xdb\xf1\xc9\x1f\x1f\x1f\xaf6\xf1\xe5\xab~\xd8\xe0\xf5m\x01\xdai\xd7\\\xff\x87\xab\x87\x8f\xbe9N\xdb~\xb8~\xba\x88\x
# ...

# %%
len(contents)
# Out:
# 167546

# %%
len(compressedContents)
# Out:
# 60624

# %%
# %%writefile mylibrary.py

def listSum(inList):
    return sum(inList)

def listMax(inList):
    return max(inList)
# Out:
# Overwriting mylibrary.py

# %%
import mylibrary

# %%
mylibrary.listMax([12,3,2,1,2])
# Out:
# 12

# %%
from mylibrary import listSum

# %%
listMax([2,231,3])
# Out:
# 231

# %%
import mylibrary as ml
