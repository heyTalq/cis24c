# %%
import matplotlib.pyplot as plt
import numpy

x = [1,2,3,4]
y1 = [2,3,45,2]
y2 = [2,99,3,34]
f , axarr = plt.subplots(2,2)
axarr[0][0].plot(x,y1)
axarr[0][1].plot(x,y2)
axarr[1][1].hist(x)
axarr[1][0].plot(x,y2)


f.subplots_adjust(hspace = 0.5)


plt.show()
